# %%
import pandas as pd
file_path = "C:\\Users\\\Silvy Nur Azkia\\OneDrive\\Desktop\\Documents\\Kuliah\\tugas kuliah\\Pemrograman dasar\\prak\\TugaspraktikumP7.csv"
df = pd.read_csv(file_path)
print(df)
# Out:
#    nama_kabupaten  kode_kecamatan  nama_kecamatan  kode_kelurahan  \
# 0        KARAWANG          321501  Karawang Barat      3215011001
# 1        KARAWANG          321501  Karawang Barat      3215011003
# 2        KARAWANG          321501  Karawang Barat      3215011005
# 3        KARAWANG          321501  Karawang Barat      3215011006
# 4        KARAWANG          321501  Karawang Barat      3215011007
# 5        KARAWANG          321501  Karawang Barat      3215011010
# 6        KARAWANG          321501  Karawang Barat      3215011011
# 7        KARAWANG          321501  Karawang Barat      3215011012
# 8        KARAWANG          321501  Karawang Barat      3215011001
# 9        KARAWANG          321501  Karawang Barat      3215011003
# 10       KARAWANG          321501  Karawang Barat      3215011005
# 11       KARAWANG          321501  Karawang Barat      3215011006
# 12       KARAWANG          321501  Karawang Barat      3215011007
# ...

# %%
import pandas as pd
file_path = "C:\\Users\\\Silvy Nur Azkia\\OneDrive\\Desktop\\Documents\\Kuliah\\tugas kuliah\\Pemrograman dasar\\prak\\TugaspraktikumP7.csv"
df = pd.read_csv(file_path)
print(df)
print("Data Awal:")
print(df.head())

# Pengecekan informasi umum tentang dataset
print("\nInformasi Dataset:")
print(df.info())

# Pengecekan nilai yang hilang
print("\nJumlah Data yang Hilang:")
print(df.isnull().sum())

# Konversi kolom 'produksi_padi' dari string ke numerik
df['produksi_padi'] = pd.to_numeric(df['produksi_padi'], errors='coerce')

# Menghapus baris dengan data yang hilang
df = df.dropna()

# Menampilkan beberapa baris data setelah pembersihan
print("\nData Setelah Pembersihan:")
print(df.head())
# Out:
#    nama_kabupaten  kode_kecamatan  nama_kecamatan  kode_kelurahan  \
# 0        KARAWANG          321501  Karawang Barat      3215011001
# 1        KARAWANG          321501  Karawang Barat      3215011003
# 2        KARAWANG          321501  Karawang Barat      3215011005
# 3        KARAWANG          321501  Karawang Barat      3215011006
# 4        KARAWANG          321501  Karawang Barat      3215011007
# 5        KARAWANG          321501  Karawang Barat      3215011010
# 6        KARAWANG          321501  Karawang Barat      3215011011
# 7        KARAWANG          321501  Karawang Barat      3215011012
# 8        KARAWANG          321501  Karawang Barat      3215011001
# 9        KARAWANG          321501  Karawang Barat      3215011003
# 10       KARAWANG          321501  Karawang Barat      3215011005
# 11       KARAWANG          321501  Karawang Barat      3215011006
# 12       KARAWANG          321501  Karawang Barat      3215011007
# ...

# %%
import pandas as pd
file_path = "C:\\Users\\\Silvy Nur Azkia\\OneDrive\\Desktop\\Documents\\Kuliah\\tugas kuliah\\Pemrograman dasar\\prak\\TugaspraktikumP7.csv"
df = pd.read_csv(file_path)
print(df)
print("Data Awal:")
print(df.head())

# Pengecekan informasi umum tentang dataset
print("\nInformasi Dataset:")
print(df.info())

# Pengecekan nilai yang hilang
print("\nJumlah Data yang Hilang:")
print(df.isnull().sum())
# Out:
#    nama_kabupaten  kode_kecamatan  nama_kecamatan  kode_kelurahan  \
# 0        KARAWANG          321501  Karawang Barat      3215011001
# 1        KARAWANG          321501  Karawang Barat      3215011003
# 2        KARAWANG          321501  Karawang Barat      3215011005
# 3        KARAWANG          321501  Karawang Barat      3215011006
# 4        KARAWANG          321501  Karawang Barat      3215011007
# 5        KARAWANG          321501  Karawang Barat      3215011010
# 6        KARAWANG          321501  Karawang Barat      3215011011
# 7        KARAWANG          321501  Karawang Barat      3215011012
# 8        KARAWANG          321501  Karawang Barat      3215011001
# 9        KARAWANG          321501  Karawang Barat      3215011003
# 10       KARAWANG          321501  Karawang Barat      3215011005
# 11       KARAWANG          321501  Karawang Barat      3215011006
# 12       KARAWANG          321501  Karawang Barat      3215011007
# ...

# %%
import pandas as pd
file_path = "C:\\Users\\\Silvy Nur Azkia\\OneDrive\\Desktop\\Documents\\Kuliah\\tugas kuliah\\Pemrograman dasar\\prak\\TugaspraktikumP7.csv"
df = pd.read_csv(file_path)
print(df)
df['produksi_padi'] = pd.to_numeric(df['produksi_padi'], errors='coerce')

# Menghapus baris dengan data yang hilang
df = df.dropna()

# Menampilkan beberapa baris data setelah pembersihan
print("\nData Setelah Pembersihan:")
print(df.head())
# Out:
#    nama_kabupaten  kode_kecamatan  nama_kecamatan  kode_kelurahan  \
# 0        KARAWANG          321501  Karawang Barat      3215011001
# 1        KARAWANG          321501  Karawang Barat      3215011003
# 2        KARAWANG          321501  Karawang Barat      3215011005
# 3        KARAWANG          321501  Karawang Barat      3215011006
# 4        KARAWANG          321501  Karawang Barat      3215011007
# 5        KARAWANG          321501  Karawang Barat      3215011010
# 6        KARAWANG          321501  Karawang Barat      3215011011
# 7        KARAWANG          321501  Karawang Barat      3215011012
# 8        KARAWANG          321501  Karawang Barat      3215011001
# 9        KARAWANG          321501  Karawang Barat      3215011003
# 10       KARAWANG          321501  Karawang Barat      3215011005
# 11       KARAWANG          321501  Karawang Barat      3215011006
# 12       KARAWANG          321501  Karawang Barat      3215011007
# ...

# %%
import pandas as pd
file_path = "C:\\Users\\\Silvy Nur Azkia\\OneDrive\\Desktop\\Documents\\Kuliah\\tugas kuliah\\Pemrograman dasar\\prak\\TugaspraktikumP7.csv"
df = pd.read_csv(file_path)
print(df)
total_produksi_per_kelurahan = df.groupby('nama_kelurahan')['produksi_padi'].sum()

# Menampilkan total produksi padi di setiap kelurahan
print("\nTotal Produksi Padi per Kelurahan:")
print(total_produksi_per_kelurahan)

# Identifikasi 5 kelurahan dengan total produksi padi tertinggi
top5_kelurahan_tertinggi = total_produksi_per_kelurahan
print("\n5 Kelurahan dengan Total Produksi Padi Tertinggi:")
print(top5_kelurahan_tertinggi)

# Identifikasi 5 kelurahan dengan total produksi padi terendah
bottom5_kelurahan_terendah = total_produksi_per_kelurahan
print("\n5 Kelurahan dengan Total Produksi Padi Terendah:")
print(bottom5_kelurahan_terendah)
# Out:
#    nama_kabupaten  kode_kecamatan  nama_kecamatan  kode_kelurahan  \
# 0        KARAWANG          321501  Karawang Barat      3215011001
# 1        KARAWANG          321501  Karawang Barat      3215011003
# 2        KARAWANG          321501  Karawang Barat      3215011005
# 3        KARAWANG          321501  Karawang Barat      3215011006
# 4        KARAWANG          321501  Karawang Barat      3215011007
# 5        KARAWANG          321501  Karawang Barat      3215011010
# 6        KARAWANG          321501  Karawang Barat      3215011011
# 7        KARAWANG          321501  Karawang Barat      3215011012
# 8        KARAWANG          321501  Karawang Barat      3215011001
# 9        KARAWANG          321501  Karawang Barat      3215011003
# 10       KARAWANG          321501  Karawang Barat      3215011005
# 11       KARAWANG          321501  Karawang Barat      3215011006
# 12       KARAWANG          321501  Karawang Barat      3215011007
# ...
